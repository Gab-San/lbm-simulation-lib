# %% [markdown]
# <a href="https://colab.research.google.com/github/Gab-San/lbm-simulation-lib/blob/main/notebooks/cuda_lid_cavity_2d_bgk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Always reset to the Colab root directory
# %cd /content

repo_name = "lbm-simulation-lib"
repo_path = f"/content/{repo_name}"

# 2. Silently force-delete the repository if it exists
# !rm -rf ${repo_name}

# 3. Clone a completely fresh copy (add token here if private)
# !git clone https://github.com/Gab-San/lbm-simulation-lib.git

# 4. Move into the pristine directory
# %cd {repo_path}

# %%
# !cmake -DLBM_ENABLE_CUDA=ON -DCMAKE_BUILD_TYPE=Release -B build && cmake --build build -j4
# !./build/simulations/lid_cavity_2d_bgk
# !./build/simulations/cuda_lid_cavity_2d_bgk

# %%
# %pip install -r scripts/requirements.txt

# !python scripts/visualize_profile.py out/data_lid_cavity_openmp_129_100_01_bgk.bin benchmarks/ghia/data_y_100.txt --title="Lid Cavity 2D Velocity Profile (OpenMP)" -o lid_cavity_openmp_129_100_01_bgk.png
# !python scripts/visualize_profile.py out/data_lid_cavity_cuda_129_100_01_bgk.bin benchmarks/ghia/data_y_100.txt --title="Lid Cavity 2D Velocity Profile (CUDA)" -o lid_cavity_cuda_129_100_01_bgk.png
