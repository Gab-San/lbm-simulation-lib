# %% [markdown]
# <a href="https://colab.research.google.com/github/Gab-San/lbm-simulation-lib/blob/solver%2Fcuda2d/notebooks/cuda_lid_cavity_2d_bgk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to lbm-simulation-lib with Colab!
#
# **TODO-LIST**:
# 1. Clone repository (with read-only access)
# 2. Move to correct branch (solver-cuda-2d)(can be squashed with previous?)
# 3. Compile with cmake
# 4. Run the code
#
# - Install the required libraries
#
# **REQUIREMENTS**:
# - This Colab Notebook shall have access to CUDA.
# - This Colab Notebook should be hosted on an hardware with NVIDIA GPUs.

# %%
# !nvcc --version
# !nvidia-smi

# %%
# !git clone https://github.com/Gab-San/lbm-simulation-lib.git
# %cd lbm-simulation-lib
# !git switch solver/cuda2d

# %%
# !cmake -DLBM_ENABLE_CUDA=ON -B build && cmake --build build -j4
